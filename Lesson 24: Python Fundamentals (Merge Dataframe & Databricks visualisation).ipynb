# %%
import pandas as pd

# %%
df_user = pd.read_csv("user_profile.csv")

df_user.head()

# %% [markdown]
# Visualisation on databricks

# %%
df = df_user[["Province", "UserID"]]
display(df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df = df_user[["Age", "UserID"]]
display(df)
# Out:
# Databricks visualization. Run in Databricks to view.

# %%
df_user.info()

# %%
df_views = pd.read_csv("viewership.csv")

df_views.head()

# %%
df_views.info()

# %%
print(df_views["UserID"].nunique())

# %% [markdown]
# Left Join

# %%
df_lft = pd.merge(df_user, df_views, on = "UserID", how = "left")
df_lft.head(1000)

# %% [markdown]
# Right Join

# %%
df_right = pd.merge(df_user, df_views, on = "UserID", how = "right")

df_right.head(1000)
